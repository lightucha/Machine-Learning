# %%
import numpy as np

# %%
# by summing up

dx = 0.001
x = np.arange(0,1,dx)
A = 0

for xk in x:
    A += (xk**2)*dx
    
print(A)
# Out:
# 0.3328335

# %%
# the number of points below curve out of the total number is a fraction of area

n = 10000

# generate n random numbers x and y

x = np.random.rand(n,1)
y = np.random.rand(n,1)

count = 0
for i in range(n):
    # compute y to f(x)
    if y[i,0] < x[i,0]**2:
        count += 1
        
# result normalized by total #
print(count/n)
# Out:
# 0.3374

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

# %matplotlib inline

# %%
# data generation
m = 5000
mu = np.array([0, 0])
sigma = np.array([[3, 1.5], 
                  [1.5, 1]])

X = np.random.multivariate_normal(mu, sigma, m)
X = np.asmatrix(X)

fig = plt.figure(figsize=(10, 6))
plt.plot(X[:,0], X[:,1], 'k.')
plt.axis('equal')
plt.show()

# %%
S = 1/(m-1)*X.T*X
S = np.asmatrix(S)
 
D, V = np.linalg.eig(S)

idx = np.argsort(-D)
D = D[idx]
V = V[:,idx]

print(D)
print(V)
# Out:
# [ 3.76671298  0.19725083]
# [[ 0.88290197 -0.46955735]
#  [ 0.46955735  0.88290197]]

# %%
h = V[1,0]/V[0,0]
xp = np.arange(-6, 6, 0.1)
yp = h*xp

fig = plt.figure(figsize=(10, 6))
plt.plot(X[:,0], X[:,1], 'k.')
plt.plot(xp, yp, 'r', linewidth=4.0)
plt.axis('equal')
plt.show()

# %%
Z = X*V[:,1]

plt.figure(figsize=(10, 6))
plt.hist(Z, 51)
plt.show()
